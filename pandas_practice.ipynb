# %%
import pandas as pd

# %%
df = pd.DataFrame({'name' : ['김지혼', '이유진', '박동현', '김민지'],
                  'english' : [90, 80, 60, 70],
                  'math' : [50, 60, 100, 20]})
df
# Out:
#   name  english  math
# 0  김지혼       90    50
# 1  이유진       80    60
# 2  박동현       60   100
# 3  김민지       70    20

# %%
sum(df['math'])/4
# Out:
# 57.5

# %%
df2 = pd.DataFrame({'제품' : ['사과', '딸기', '수박'],
                   '가격' : [1800, 1500, 3000],
                   '판매량' : [24, 38, 13]})
df2
# Out:
#    제품    가격  판매량
# 0  사과  1800   24
# 1  딸기  1500   38
# 2  수박  3000   13

# %%
avg = sum(df2['가격'])/3
avg
# Out:
# 2100.0

# %%
df_exam = pd.read_excel('Documents/python_train/excel_exam.xlsx')
df_exam
# Out:
#     id  class  math  english  science
# 0    1      1    50       98       50
# 1    2      1    60       97       60
# 2    3      1    45       86       78
# 3    4      1    30       98       58
# 4    5      2    25       80       65
# 5    6      2    50       89       98
# 6    7      2    80       90       45
# 7    8      2    90       78       25
# 8    9      3    20       98       15
# 9   10      3    50       98       45
# 10  11      3    65       65       65
# 11  12      3    45       85       32
# 12  13      4    46       98       65
# 13  14      4    48       87       12
# 14  15      4    75       56       78
# 15  16      4    58       98       65
# 16  17      5    65       68       98
# 17  18      5    80       78       90
# 18  19      5    89       68       87
# 19  20      5    78       83       58

# %%
sum(df_exam['english'])/20
# Out:
# 84.9

# %%
df_exam_novar = pd.read_excel('Documents/python_train/excel_exam_novar.xlsx', sheet_name = 0, header = None)

# %%
df_exam_novar
# Out:
#    0  1   2   3   4
# 0  1  1  50  98  50
# 1  2  1  60  97  60
# 2  3  2  25  80  65
# 3  4  2  50  89  98
# 4  5  3  20  98  15
# 5  6  3  50  98  45
# 6  7  4  46  98  65
# 7  8  4  48  87  12

# %%
df_csv_exam = pd.read_csv('Documents/python_train/csv_exam.csv')

# %%
df_csv_exam
# Out:
#     id  class  math  english  science
# 0    1      1    50       98       50
# 1    2      1    60       97       60
# 2    3      1    45       86       78
# 3    4      1    30       98       58
# 4    5      2    25       80       65
# 5    6      2    50       89       98
# 6    7      2    80       90       45
# 7    8      2    90       78       25
# 8    9      3    20       98       15
# 9   10      3    50       98       45
# 10  11      3    65       65       65
# 11  12      3    45       85       32
# 12  13      4    46       98       65
# 13  14      4    48       87       12
# 14  15      4    75       56       78
# 15  16      4    58       98       65
# 16  17      5    65       68       98
# 17  18      5    80       78       90
# 18  19      5    89       68       87
# 19  20      5    78       83       58

# %%
df_midterm = pd.DataFrame({'english' : [90, 80, 60, 70],
                          'math' : [50, 60, 100, 20],
                          'nclass' : [1, 1, 2, 2]})
df_midterm
# Out:
#    english  math  nclass
# 0       90    50       1
# 1       80    60       1
# 2       60   100       2
# 3       70    20       2

# %%
df_midterm.to_csv('Documents/python_train/output_newdata.csv', index = False)
df_midterm
# Out:
#    english  math  nclass
# 0       90    50       1
# 1       80    60       1
# 2       60   100       2
# 3       70    20       2
